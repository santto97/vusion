# %%
from joblib import Parallel, delayed
from skimage import io, color
import csv
import cv2
import matplotlib.pyplot as plt
import multiprocessing
import numpy as np
import os


img = cv2.imread("28/6_590nm.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

y = len(img)
x = len(img[1])
avg = np.zeros((y,x,3),dtype=int)
avg_color = img.mean(axis=0).mean(axis=0)

print(avg_color)

for i in range(y):
    for j in range(x):
        avg[i][j][0]=round(avg_color[0])
        avg[i][j][1]=round(avg_color[1])
        avg[i][j][2]=round(avg_color[2])
for i in range(y):
    for j in range(x):
        aux1 = (img[i][j][0]**2+img[i][j][1]**2+img[i][j][2]**2)**0.5
        
        if aux1*0.65 >= (avg[i][j][0]**2+avg[i][j][1]**2+avg[i][j][2]**2)**0.5:
            img[i][j][0] = 255
            img[i][j][1] = 0
            img[i][j][2] = 0
        
plt.imshow(img)
# Out:
# [73.82753581 73.82753581 73.82753581]
